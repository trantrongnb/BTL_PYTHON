# %%
from model import My_Advanced_Model

# %%
model=My_Advanced_Model(5)

# %%
model
# Out:
# My_Advanced_Model(
#   (block1): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEBlock(
#         (fc1): Linear(in_features=64, out_features=4, bias=True)
#         (fc2): Linear(in_features=4, out_features=64, bias=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): Dropout(p=0.3, inplace=False)
#   )
#   (block2): Sequential(
#     (0): ResidualBlock(
# ...

# %%
for name, param in model.named_parameters():
    print(f"Layer: {name}")
    print(f"Weight data:\n{param.data}")
    print("-" * 50)
# Out:
# Layer: block1.0.conv1.weight
# Weight data:
# tensor([[[[-3.1381e-01, -2.7241e-02,  2.0894e-02],
#           [ 6.0606e-02,  1.9147e-01,  2.7688e-01],
#           [ 2.7906e-01,  9.6321e-02,  2.6269e-01]]],
#
#
#         [[[ 1.2165e-01, -2.5777e-02, -1.3358e-01],
#           [ 2.8478e-01, -2.0994e-01, -2.9079e-02],
#           [-1.5526e-02,  2.0014e-02, -2.0018e-02]]],
#
#
#         [[[-2.0460e-01,  1.6402e-01,  2.8198e-01],
#           [ 1.7783e-01, -2.9679e-01, -1.2898e-01],
#           [ 1.3878e-01, -1.7325e-01,  1.3281e-01]]],
#
#
#         [[[-2.1800e-01,  1.4340e-01, -2.8352e-01],
#           [ 1.0088e-01, -1.7651e-01,  3.3137e-01],
#           [-1.5150e-02, -4.3210e-02,  1.3081e-01]]],
#
#
#         [[[ 9.2299e-02, -2.4737e-01,  2.2927e-02],
#           [ 1.5923e-01, -2.1066e-02, -2.9128e-01],
#           [-2.2817e-01, -6.1045e-02,  1.2942e-01]]],
#
#
#         [[[-6.5579e-02, -3.3150e-02, -1.7174e-01],
#           [ 4.2812e-02,  3.1494e-01, -2.5926e-01],
# ...

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f"Tổng số tham số: {total_params:,}")
# Out:
# Tổng số tham số: 5,040,193
